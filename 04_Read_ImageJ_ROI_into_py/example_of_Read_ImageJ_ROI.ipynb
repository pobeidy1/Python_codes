# %%
#!pip install -U roifile tifffile matplotlib

# %%
from roifile import ImagejRoi
roi2 = ImagejRoi.fromfile('0098-0062-0110_a131.roi')

# %%
roi2.plot()

# %%
b=roi2.coordinates()
b.shape
# Out:
# (983, 2)

# %%
import matplotlib.pylab as plt
plt.scatter(b[:,0], b[:,1])
